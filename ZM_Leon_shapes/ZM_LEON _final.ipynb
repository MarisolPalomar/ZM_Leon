# %% [markdown]
# # **ZM → LEÓN, GUANAJUATO**

# %% [markdown]
# ## **LIBRERÍAS A UTILIZAR**

# %%
from IPython.core.display import HTML
HTML("<script>Jupyter.notebook.kernel.restart()</script>")

# %%
# !pip install mapclassify
# Out:
# Collecting mapclassify
#   Downloading mapclassify-2.4.2-py3-none-any.whl (38 kB)
# Collecting pandas>=1.0
#   Downloading pandas-1.2.4-cp37-cp37m-manylinux1_x86_64.whl (9.9 MB)
#      |████████████████████████████████| 9.9 MB 8.3 MB/s eta 0:00:01
# Collecting networkx
#   Downloading networkx-2.5.1-py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 46.9 MB/s eta 0:00:01
# Collecting scipy>=1.0
#   Downloading scipy-1.6.3-cp37-cp37m-manylinux1_x86_64.whl (27.4 MB)
#      |████████████████████████████████| 27.4 MB 48.3 MB/s eta 0:00:01    |███████▉                        | 6.7 MB 48.3 MB/s eta 0:00:01
# Collecting numpy>=1.3
#   Downloading numpy-1.20.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.3 MB)
#      |████████████████████████████████| 15.3 MB 40.4 MB/s eta 0:00:01
# Collecting scikit-learn
#   Downloading scikit_learn-0.24.2-cp37-cp37m-manylinux2010_x86_64.whl (22.3 MB)
#      |████████████████████████████████| 22.3 MB 59.2 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas>=1.0->mapclassify) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas>=1.0->mapclassify) (2021.1)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=1.0->mapclassify) (1.15.0)
# Requirement already satisfied: decorator<5,>=4.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from networkx->mapclassify) (4.4.2)
# Collecting joblib>=0.11
#   Downloading joblib-1.0.1-py3-none-any.whl (303 kB)
#      |████████████████████████████████| 303 kB 27.6 MB/s eta 0:00:01
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-2.1.0-py3-none-any.whl (12 kB)
# Installing collected packages: numpy, threadpoolctl, scipy, joblib, scikit-learn, pandas, networkx, mapclassify
# Successfully installed joblib-1.0.1 mapclassify-2.4.2 networkx-2.5.1 numpy-1.20.3 pandas-1.2.4 scikit-learn-0.24.2 scipy-1.6.3 threadpoolctl-2.1.0

# %%
# !pip install libpysal
# Out:
# Collecting libpysal
#   Downloading libpysal-4.4.0-py3-none-any.whl (2.4 MB)
#      |████████████████████████████████| 2.4 MB 4.0 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from libpysal) (1.20.3)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.9.3-py3-none-any.whl (115 kB)
#      |████████████████████████████████| 115 kB 28.5 MB/s eta 0:00:01
# Requirement already satisfied: requests in /srv/conda/envs/notebook/lib/python3.7/site-packages (from libpysal) (2.25.1)
# Requirement already satisfied: jinja2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from libpysal) (2.11.3)
# Requirement already satisfied: pandas in /srv/conda/envs/notebook/lib/python3.7/site-packages (from libpysal) (1.2.4)
# Requirement already satisfied: scipy>=0.11 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from libpysal) (1.6.3)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.2.1-py3-none-any.whl (33 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jinja2->libpysal) (1.1.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas->libpysal) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas->libpysal) (2021.1)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas->libpysal) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests->libpysal) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests->libpysal) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests->libpysal) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests->libpysal) (1.26.3)
# Installing collected packages: soupsieve, beautifulsoup4, libpysal
# Successfully installed beautifulsoup4-4.9.3 libpysal-4.4.0 soupsieve-2.2.1

# %%
# !pip install fiona
# !pip install rtree
# !pip install pygeos
# Out:
# Collecting fiona
#   Downloading Fiona-1.8.19-cp37-cp37m-manylinux1_x86_64.whl (15.3 MB)
#      |████████████████████████████████| 15.3 MB 4.4 MB/s eta 0:00:01
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: attrs>=17 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from fiona) (20.3.0)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.1-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: six>=1.7 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from fiona) (1.15.0)
# Requirement already satisfied: certifi in /srv/conda/envs/notebook/lib/python3.7/site-packages (from fiona) (2020.12.5)
# Collecting click<8,>=4.0
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
#      |████████████████████████████████| 82 kB 1.6 MB/s  eta 0:00:01
# Installing collected packages: click, munch, cligj, click-plugins, fiona
# Successfully installed click-7.1.2 click-plugins-1.1.1 cligj-0.7.1 fiona-1.8.19 munch-2.5.0
# Collecting rtree
#   Downloading Rtree-0.9.7-cp37-cp37m-manylinux2010_x86_64.whl (994 kB)
#      |████████████████████████████████| 994 kB 3.9 MB/s eta 0:00:01
# Installing collected packages: rtree
# Successfully installed rtree-0.9.7
# Collecting pygeos
#   Downloading pygeos-0.10-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 4.3 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.13 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pygeos) (1.20.3)
# Installing collected packages: pygeos
# Successfully installed pygeos-0.10

# %%
import fiona
import rtree
import pygeos

# %%
# !pip install geopandas
# Out:
# Collecting geopandas
#   Downloading geopandas-0.9.0-py2.py3-none-any.whl (994 kB)
#      |████████████████████████████████| 994 kB 4.4 MB/s eta 0:00:01
# Requirement already satisfied: fiona>=1.8 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from geopandas) (1.8.19)
# Collecting pyproj>=2.2.0
#   Downloading pyproj-3.0.1-cp37-cp37m-manylinux2010_x86_64.whl (6.5 MB)
#      |████████████████████████████████| 6.5 MB 6.9 MB/s eta 0:00:01
# Requirement already satisfied: pandas>=0.24.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from geopandas) (1.2.4)
# Collecting shapely>=1.6
#   Downloading Shapely-1.7.1-cp37-cp37m-manylinux1_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 64.5 MB/s eta 0:00:01
# Requirement already satisfied: attrs>=17 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (20.3.0)
# Requirement already satisfied: click-plugins>=1.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (0.7.1)
# Requirement already satisfied: click<8,>=4.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (7.1.2)
# Requirement already satisfied: certifi in /srv/conda/envs/notebook/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (2020.12.5)
# Requirement already satisfied: munch in /srv/conda/envs/notebook/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: six>=1.7 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (1.15.0)
# Requirement already satisfied: numpy>=1.16.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas>=0.24.0->geopandas) (1.20.3)
# Requirement already satisfied: pytz>=2017.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas>=0.24.0->geopandas) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas>=0.24.0->geopandas) (2.8.1)
# Installing collected packages: shapely, pyproj, geopandas
# Successfully installed geopandas-0.9.0 pyproj-3.0.1 shapely-1.7.1

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.4.2-cp37-cp37m-manylinux1_x86_64.whl (10.3 MB)
#      |████████████████████████████████| 10.3 MB 4.6 MB/s eta 0:00:01
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.1-cp37-cp37m-manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 50.4 MB/s eta 0:00:01
# Requirement already satisfied: pyparsing>=2.2.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (2.4.7)
# Collecting pillow>=6.2.0
#   Downloading Pillow-8.2.0-cp37-cp37m-manylinux1_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 60.6 MB/s eta 0:00:01
# Collecting cycler>=0.10
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (2.8.1)
# Requirement already satisfied: numpy>=1.16 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (1.20.3)
# Requirement already satisfied: six in /srv/conda/envs/notebook/lib/python3.7/site-packages (from cycler>=0.10->matplotlib) (1.15.0)
# Installing collected packages: pillow, kiwisolver, cycler, matplotlib
# Successfully installed cycler-0.10.0 kiwisolver-1.3.1 matplotlib-3.4.2 pillow-8.2.0

# %%
import numpy as np
import mapclassify
import pandas as pd
import libpysal as ps
import geopandas as gpd
import matplotlib as mpl
import matplotlib.pyplot as plt
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/geopandas/_compat.py:110: UserWarning: The Shapely GEOS version (3.8.0-CAPI-1.13.1 ) is incompatible with the GEOS version PyGEOS was compiled with (3.9.1-CAPI-1.14.2). Conversions between both will be slow.
#   shapely_geos_version, geos_capi_version_string

# %%
# !pip install contextily
# Out:
# Collecting contextily
#   Downloading contextily-1.1.0-py3-none-any.whl (24 kB)
# Collecting rasterio
#   Downloading rasterio-1.2.3-cp37-cp37m-manylinux1_x86_64.whl (19.1 MB)
#      |████████████████████████████████| 19.1 MB 4.4 MB/s eta 0:00:01
# Collecting mercantile
#   Downloading mercantile-1.2.1-py3-none-any.whl (14 kB)
# Collecting geopy
#   Downloading geopy-2.1.0-py3-none-any.whl (112 kB)
#      |████████████████████████████████| 112 kB 40.4 MB/s eta 0:00:01
# Requirement already satisfied: pillow in /srv/conda/envs/notebook/lib/python3.7/site-packages (from contextily) (8.2.0)
# Requirement already satisfied: requests in /srv/conda/envs/notebook/lib/python3.7/site-packages (from contextily) (2.25.1)
# Requirement already satisfied: joblib in /srv/conda/envs/notebook/lib/python3.7/site-packages (from contextily) (1.0.1)
# Requirement already satisfied: matplotlib in /srv/conda/envs/notebook/lib/python3.7/site-packages (from contextily) (3.4.2)
# Collecting geographiclib<2,>=1.49
#   Downloading geographiclib-1.50-py3-none-any.whl (38 kB)
# Requirement already satisfied: cycler>=0.10 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib->contextily) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib->contextily) (2.8.1)
# Requirement already satisfied: numpy>=1.16 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib->contextily) (1.20.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib->contextily) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib->contextily) (1.3.1)
# Requirement already satisfied: six in /srv/conda/envs/notebook/lib/python3.7/site-packages (from cycler>=0.10->matplotlib->contextily) (1.15.0)
# Requirement already satisfied: click>=3.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from mercantile->contextily) (7.1.2)
# Requirement already satisfied: certifi in /srv/conda/envs/notebook/lib/python3.7/site-packages (from rasterio->contextily) (2020.12.5)
# Requirement already satisfied: cligj>=0.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from rasterio->contextily) (0.7.1)
# Requirement already satisfied: click-plugins in /srv/conda/envs/notebook/lib/python3.7/site-packages (from rasterio->contextily) (1.1.1)
# Requirement already satisfied: attrs in /srv/conda/envs/notebook/lib/python3.7/site-packages (from rasterio->contextily) (20.3.0)
# Collecting snuggs>=1.4.1
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Collecting affine
#   Downloading affine-2.3.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests->contextily) (1.26.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests->contextily) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests->contextily) (2.10)
# Installing collected packages: snuggs, geographiclib, affine, rasterio, mercantile, geopy, contextily
# Successfully installed affine-2.3.0 contextily-1.1.0 geographiclib-1.50 geopy-2.1.0 mercantile-1.2.1 rasterio-1.2.3 snuggs-1.4.7

# %%
import matplotlib.patches as mpatches
import contextily as ctx

# %% [markdown]
# ## **BD: AGEBs SHAPE, INEGI 2020**

# %%
AGEBS= gpd.read_file('AgebsUrbanas_Leon_ZM.shp')
print ('Forma de los datos:',AGEBS.shape)
AGEBS.head(5)
# Out:
# Forma de los datos: (797, 5)
#           CVEGEO CVE_ENT CVE_MUN CVE_AGEB  \
# 0  1103700011083      11     037     1083
# 1  110370019105A      11     037     105A
# 2  1103700241079      11     037     1079
# 3  1103700241064      11     037     1064
# 4  1103700010329      11     037     0329
#
#                                             geometry
# 0  POLYGON ((2561453.820 993198.977, 2561433.546 ...
# 1  POLYGON ((2557132.016 996807.810, 2557169.761 ...
# 2  POLYGON ((2554496.562 1005752.397, 2554483.340...
# 3  POLYGON ((2554094.826 1006325.869, 2554068.088...
# 4  POLYGON ((2560671.896 992420.641, 2560655.693 ...

# %%
AGEBS.crs
# Out:
# <Projected CRS: EPSG:6372>
# Name: Mexico ITRF2008 / LCC
# Axis Info [cartesian]:
# - N[north]: Northing (metre)
# - E[east]: Easting (metre)
# Area of Use:
# - name: Mexico - onshore and offshore.
# - bounds: (-122.19, 12.1, -84.64, 32.72)
# Coordinate Operation:
# - name: Mexico LCC
# - method: Lambert Conic Conformal (2SP)
# Datum: Mexico ITRF2008
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %% [markdown]
# ## **BD: ÁREAS VERDES, INEGI 2020**

# %%
Area_Verde= gpd.read_file('SIA_Leon_ZM.shp')
Area_Verde.head()
# Out:
#       CVEGEO CVE_ENT CVE_MUN CVE_LOC  CONDICION GEOGRAFICO    NOMSERV  \
# 0  110370001      11     037    0001  No Aplica   Camellón  No Aplica
# 1  110370001      11     037    0001  No Aplica   Camellón  No Aplica
# 2  110370001      11     037    0001  No Aplica   Camellón  No Aplica
# 3  110370001      11     037    0001  No Aplica   Camellón  No Aplica
# 4  110370001      11     037    0001  No Aplica   Camellón  No Aplica
#
#        TIPO  CVE_SERV  AMBITO  \
# 0  Camellón         1  Urbana
# 1  Camellón         2  Urbana
# 2  Camellón         3  Urbana
# 3  Camellón         4  Urbana
# 4  Camellón         5  Urbana
#
#                                             geometry
# 0  POLYGON ((2558110.204 994028.560, 2558110.623 ...
# 1  POLYGON ((2557192.107 993825.819, 2557191.720 ...
# 2  POLYGON ((2560925.631 993157.571, 2560931.757 ...
# 3  POLYGON ((2558487.705 993485.603, 2558487.624 ...
# 4  POLYGON ((2560474.702 993645.248, 2560474.997 ...

# %%
Area_Verde.crs
# Out:
# <Projected CRS: EPSG:6372>
# Name: Mexico ITRF2008 / LCC
# Axis Info [cartesian]:
# - N[north]: Northing (metre)
# - E[east]: Easting (metre)
# Area of Use:
# - name: Mexico - onshore and offshore.
# - bounds: (-122.19, 12.1, -84.64, 32.72)
# Coordinate Operation:
# - name: Mexico LCC
# - method: Lambert Conic Conformal (2SP)
# Datum: Mexico ITRF2008
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %% [markdown]
# ## **BD: MEDICIÓN DE POBREZA, CONEVAL 2015**

# %%
Pobreza_ageb = pd.read_csv ('RangoPobreza_LeonZM_new.csv')
Pobreza_ageb.head(5)
# Out:
#    cve_ent     nom_ent  cve_mun nom_mun         cvegeo cve_ageb   pobreza  \
# 0       11  Guanajuato    11020    Leon  1102000000000     0000  (18, 34)
# 1       11  Guanajuato    11020    Leon  1102000010143     0143  (18, 34)
# 2       11  Guanajuato    11020    Leon  1102000010181     0181  (18, 34)
# 3       11  Guanajuato    11020    Leon  1102000010251     0251  (18, 34)
# 4       11  Guanajuato    11020    Leon  1102000010270     0270  (18, 34)
#
#   pobreza_ext
# 0     (0, 20)
# 1     (0, 20)
# 2     (0, 20)
# 3     (0, 20)
# 4     (0, 20)

# %% [markdown]
# ## **HOMOLOGAR BASES DE DATOS**

# %%
AGEBS = AGEBS.rename({'CVEGEO':'Clave_AGEB'}, axis=1)
Pobreza_ageb = Pobreza_ageb.rename({'cvegeo':'Clave_AGEB'}, axis=1)
Pobreza_ageb = Pobreza_ageb.rename({'pobreza':'Rango_Pobreza'}, axis=1)
Pobreza_ageb = Pobreza_ageb.rename({'pobreza_ext':'Rango_PExtrema'}, axis=1)

# %%
Pobreza_ageb=Pobreza_ageb.dropna()

# %%
Pobreza_ageb['Min_RP'] = Pobreza_ageb.Rango_Pobreza.str.extract('(\d+)').astype(int)
Pobreza_ageb['Max_RP'] = Pobreza_ageb.Rango_Pobreza.str.extract('( \d+)').astype(int)
Pobreza_ageb['Pobre_AV'] = ((Pobreza_ageb['Min_RP'] + Pobreza_ageb['Max_RP']) / 2)
Pobreza_ageb2 = Pobreza_ageb[['Clave_AGEB','nom_mun', 'Rango_Pobreza', 'Pobre_AV' ]]

# %%
Pobreza_ageb2.set_index('Clave_AGEB')
AGEBS.set_index('Clave_AGEB')
# Out:
#               CVE_ENT CVE_MUN CVE_AGEB  \
# Clave_AGEB
# 1103700011083      11     037     1083
# 110370019105A      11     037     105A
# 1103700241079      11     037     1079
# 1103700241064      11     037     1064
# 1103700010329      11     037     0329
# ...               ...     ...      ...
# 1102004137827      11     020     7827
# 1102004137831      11     020     7831
# 1102004297846      11     020     7846
# 1102012567850      11     020     7850
# 1102012697865      11     020     7865
#
#                                                         geometry
# Clave_AGEB
# 1103700011083  POLYGON ((2561453.820 993198.977, 2561433.546 ...
# 110370019105A  POLYGON ((2557132.016 996807.810, 2557169.761 ...
# 1103700241079  POLYGON ((2554496.562 1005752.397, 2554483.340...
# 1103700241064  POLYGON ((2554094.826 1006325.869, 2554068.088...
# 1103700010329  POLYGON ((2560671.896 992420.641, 2560655.693 ...
# ...                                                          ...
# 1102004137827  POLYGON ((2537213.768 1000910.999, 2537134.862...
# 1102004137831  POLYGON ((2537213.768 1000910.999, 2537234.432...
# 1102004297846  POLYGON ((2538712.682 1000130.509, 2538788.806...
# 1102012567850  POLYGON ((2530341.108 1002512.253, 2530358.278...
# 1102012697865  POLYGON ((2533731.628 1005422.589, 2533731.355...
#
# [797 rows x 4 columns]

# %%
Pobreza_AGEB = AGEBS.merge(Pobreza_ageb2 ,left_on='Clave_AGEB', right_on='Clave_AGEB',how='left')
Pobreza_A = Pobreza_AGEB.copy()
print ('Forma de los datos:',Pobreza_AGEB.shape)
Pobreza_AGEB.head()
# Out:
# Forma de los datos: (797, 8)
#       Clave_AGEB CVE_ENT CVE_MUN CVE_AGEB  \
# 0  1103700011083      11     037     1083
# 1  110370019105A      11     037     105A
# 2  1103700241079      11     037     1079
# 3  1103700241064      11     037     1064
# 4  1103700010329      11     037     0329
#
#                                             geometry               nom_mun  \
# 0  POLYGON ((2561453.820 993198.977, 2561433.546 ...                   NaN
# 1  POLYGON ((2557132.016 996807.810, 2557169.761 ...                   NaN
# 2  POLYGON ((2554496.562 1005752.397, 2554483.340...                   NaN
# 3  POLYGON ((2554094.826 1006325.869, 2554068.088...                   NaN
# 4  POLYGON ((2560671.896 992420.641, 2560655.693 ...  Silao de la Victoria
#
#   Rango_Pobreza  Pobre_AV
# 0           NaN       NaN
# 1           NaN       NaN
# 2           NaN       NaN
# 3           NaN       NaN
# 4     (70, 100)      85.0

# %%
Pobreza_A = Pobreza_A.fillna(0)
Pobreza_A.head()
# Out:
#       Clave_AGEB CVE_ENT CVE_MUN CVE_AGEB  \
# 0  1103700011083      11     037     1083
# 1  110370019105A      11     037     105A
# 2  1103700241079      11     037     1079
# 3  1103700241064      11     037     1064
# 4  1103700010329      11     037     0329
#
#                                             geometry               nom_mun  \
# 0  POLYGON ((2561453.820 993198.977, 2561433.546 ...                     0
# 1  POLYGON ((2557132.016 996807.810, 2557169.761 ...                     0
# 2  POLYGON ((2554496.562 1005752.397, 2554483.340...                     0
# 3  POLYGON ((2554094.826 1006325.869, 2554068.088...                     0
# 4  POLYGON ((2560671.896 992420.641, 2560655.693 ...  Silao de la Victoria
#
#   Rango_Pobreza  Pobre_AV
# 0             0       0.0
# 1             0       0.0
# 2             0       0.0
# 3             0       0.0
# 4     (70, 100)      85.0

# %%
Pobreza_AGEB = Pobreza_AGEB.dropna()

# %%
Pobreza_A.crs
# Out:
# <Projected CRS: EPSG:6372>
# Name: Mexico ITRF2008 / LCC
# Axis Info [cartesian]:
# - N[north]: Northing (metre)
# - E[east]: Easting (metre)
# Area of Use:
# - name: Mexico - onshore and offshore.
# - bounds: (-122.19, 12.1, -84.64, 32.72)
# Coordinate Operation:
# - name: Mexico LCC
# - method: Lambert Conic Conformal (2SP)
# Datum: Mexico ITRF2008
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
Pobreza_A=Pobreza_A.to_crs(epsg=3857)

# %%
mapclassify.NaturalBreaks(Pobreza_A['Pobre_AV'].values, k=5)
# Out:
# NaturalBreaks
#
#    Interval      Count
# ----------------------
# [ 0.00,  9.00] |   403
# ( 9.00, 26.00] |   149
# (26.00, 42.00] |   133
# (42.00, 60.00] |    86
# (60.00, 85.00] |    26

# %% [markdown]
# ## **MAPA DE POBREZA POR AGEBs**

# %%
fig, ax = plt.subplots(1,figsize=(16, 18)) 
Base = Pobreza_A.plot(column='Pobre_AV', 
              alpha=1, 
              scheme='NaturalBreaks', 
              legend=True, 
              cmap='YlOrRd',
              classification_kwds={'k':5},
              figsize=(8,8),
              ax=ax)
plt.title("RANGO DE POBREZA EN LA ZM DE LEÓN (%)", size = 25)
ax.set_axis_off() 
ctx.add_basemap(ax, source=ctx.providers.Stamen.TonerLite, alpha=0.3) 
plt.show()

# %%
Pobreza_AGEB=Pobreza_AGEB.to_crs(epsg=3857)

# %% [markdown]
# ## **MAPA DE POBREZA EXTREMA POR AGEBs**

# %%
fig, ax = plt.subplots(1,figsize=(16, 18)) 
Base = Pobreza_AGEB.plot(column='Pobre_AV', 
              alpha=1, 
              scheme='NaturalBreaks', 
              legend=True, 
              cmap='YlOrRd',
              classification_kwds={'k':5},
              figsize=(8,8),
              ax=ax)
plt.title("RANGO DE POBREZA (2015) EN LA ZM DE LEÓN (%)", size = 25)
ax.set_axis_off() 
ctx.add_basemap(ax, source=ctx.providers.Stamen.TonerLite, alpha=0.3) 
plt.show()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ## **ÁREAS VERDES → OPEN STREET MAPS**

# %%
# !pip install osmnx
import osmnx as ox
# Out:
# Collecting osmnx
#   Downloading osmnx-1.1.1-py2.py3-none-any.whl (93 kB)
#      |████████████████████████████████| 93 kB 2.0 MB/s eta 0:00:011
# Requirement already satisfied: pandas>=1.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from osmnx) (1.2.4)
# Requirement already satisfied: Rtree>=0.9 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from osmnx) (0.9.7)
# Requirement already satisfied: Shapely>=1.7 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from osmnx) (1.7.1)
# Requirement already satisfied: networkx>=2.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from osmnx) (2.5.1)
# Requirement already satisfied: pyproj>=2.6 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from osmnx) (3.0.1)
# Requirement already satisfied: geopandas>=0.9 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from osmnx) (0.9.0)
# Requirement already satisfied: numpy>=1.19 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from osmnx) (1.20.3)
# Requirement already satisfied: matplotlib>=3.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from osmnx) (3.4.2)
# Requirement already satisfied: requests>=2.25 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from osmnx) (2.25.1)
# Requirement already satisfied: fiona>=1.8 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from geopandas>=0.9->osmnx) (1.8.19)
# Requirement already satisfied: click-plugins>=1.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from fiona>=1.8->geopandas>=0.9->osmnx) (1.1.1)
# Requirement already satisfied: munch in /srv/conda/envs/notebook/lib/python3.7/site-packages (from fiona>=1.8->geopandas>=0.9->osmnx) (2.5.0)
# Requirement already satisfied: six>=1.7 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from fiona>=1.8->geopandas>=0.9->osmnx) (1.15.0)
# Requirement already satisfied: attrs>=17 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from fiona>=1.8->geopandas>=0.9->osmnx) (20.3.0)
# Requirement already satisfied: certifi in /srv/conda/envs/notebook/lib/python3.7/site-packages (from fiona>=1.8->geopandas>=0.9->osmnx) (2020.12.5)
# Requirement already satisfied: click<8,>=4.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from fiona>=1.8->geopandas>=0.9->osmnx) (7.1.2)
# Requirement already satisfied: cligj>=0.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from fiona>=1.8->geopandas>=0.9->osmnx) (0.7.1)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib>=3.3->osmnx) (2.8.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib>=3.3->osmnx) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib>=3.3->osmnx) (8.2.0)
# Requirement already satisfied: cycler>=0.10 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib>=3.3->osmnx) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib>=3.3->osmnx) (2.4.7)
# Requirement already satisfied: decorator<5,>=4.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from networkx>=2.5->osmnx) (4.4.2)
# Requirement already satisfied: pytz>=2017.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas>=1.1->osmnx) (2021.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests>=2.25->osmnx) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests>=2.25->osmnx) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests>=2.25->osmnx) (1.26.3)
# Installing collected packages: osmnx
# Successfully installed osmnx-1.1.1

# %%
# !pip install git+git://github.com/geopandas/geopandas.git
# Out:
# Collecting git+git://github.com/geopandas/geopandas.git
#   Cloning git://github.com/geopandas/geopandas.git to /tmp/pip-req-build-so2vmd9f
#   Running command git clone -q git://github.com/geopandas/geopandas.git /tmp/pip-req-build-so2vmd9f
# Requirement already satisfied: pandas>=0.24.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from geopandas==0.9.0+24.ga26bde2) (1.2.4)
# Requirement already satisfied: shapely>=1.6 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from geopandas==0.9.0+24.ga26bde2) (1.7.1)
# Requirement already satisfied: fiona>=1.8 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from geopandas==0.9.0+24.ga26bde2) (1.8.19)
# Requirement already satisfied: pyproj>=2.2.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from geopandas==0.9.0+24.ga26bde2) (3.0.1)
# Requirement already satisfied: six>=1.7 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from fiona>=1.8->geopandas==0.9.0+24.ga26bde2) (1.15.0)
# Requirement already satisfied: cligj>=0.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from fiona>=1.8->geopandas==0.9.0+24.ga26bde2) (0.7.1)
# Requirement already satisfied: attrs>=17 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from fiona>=1.8->geopandas==0.9.0+24.ga26bde2) (20.3.0)
# Requirement already satisfied: munch in /srv/conda/envs/notebook/lib/python3.7/site-packages (from fiona>=1.8->geopandas==0.9.0+24.ga26bde2) (2.5.0)
# Requirement already satisfied: certifi in /srv/conda/envs/notebook/lib/python3.7/site-packages (from fiona>=1.8->geopandas==0.9.0+24.ga26bde2) (2020.12.5)
# Requirement already satisfied: click<8,>=4.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from fiona>=1.8->geopandas==0.9.0+24.ga26bde2) (7.1.2)
# Requirement already satisfied: click-plugins>=1.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from fiona>=1.8->geopandas==0.9.0+24.ga26bde2) (1.1.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas>=0.24.0->geopandas==0.9.0+24.ga26bde2) (2.8.1)
# Requirement already satisfied: numpy>=1.16.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas>=0.24.0->geopandas==0.9.0+24.ga26bde2) (1.20.3)
# Requirement already satisfied: pytz>=2017.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas>=0.24.0->geopandas==0.9.0+24.ga26bde2) (2021.1)
# Building wheels for collected packages: geopandas
#   Building wheel for geopandas (setup.py) ... done
#   Created wheel for geopandas: filename=geopandas-0.9.0+24.ga26bde2-py2.py3-none-any.whl size=995296 sha256=fbebd9120538a29deeb18e030157b3d6a195028529ff0428969a160e5deca716
#   Stored in directory: /tmp/pip-ephem-wheel-cache-r6mcxlkp/wheels/cf/3e/0b/6475054094c2b1ea054158ac1fdcf749fb92f5b512377e4cf8
# Successfully built geopandas
# Installing collected packages: geopandas
#   Attempting uninstall: geopandas
#     Found existing installation: geopandas 0.9.0
#     Uninstalling geopandas-0.9.0:
#       Successfully uninstalled geopandas-0.9.0
# Successfully installed geopandas-0.9.0+24.ga26bde2

# %%
tags = {'leisure': True}
AreaV = ox.geometries_from_place('Guanajuato', tags)
AreaV.head(10)
# Out:
#                            leisure                         name     sport  \
# element_type osmid
# node         4433052949      pitch  Estadio de Beisbol La Unión  baseball
#              6199734157  bandstand                      Quiosco       NaN
# way          211713778        park              Plaza Principal       NaN
#              211737071        park              Plaza Principal       NaN
#              211737822     stadium               Plaza de Toros       NaN
#              211740544      garden              Jardin del Arte       NaN
#              234375861        park                          NaN       NaN
#              234375862       pitch                          NaN    soccer
#              234376477       pitch                    Deportiva       NaN
#              247142027        park                          NaN       NaN
#
#                                                                   geometry  \
# element_type osmid
# node         4433052949                        POINT (-100.72718 20.04002)
#              6199734157                        POINT (-100.67831 20.05212)
# way          211713778   POLYGON ((-100.51092 20.14931, -100.51091 20.1...
#              211737071   POLYGON ((-100.51668 20.00401, -100.51613 20.0...
#              211737822   POLYGON ((-100.51491 20.00238, -100.51483 20.0...
#              211740544   POLYGON ((-100.72102 20.03304, -100.72111 20.0...
#              234375861   POLYGON ((-100.51150 20.14845, -100.51095 20.1...
#              234375862   POLYGON ((-100.51180 20.15155, -100.51119 20.1...
#              234376477   POLYGON ((-100.51470 20.15431, -100.51447 20.1...
#              247142027   POLYGON ((-100.80569 20.28354, -100.80532 20.2...
#
#                           access wheelchair  \
# element_type osmid
# node         4433052949      NaN        NaN
#              6199734157  private         no
# way          211713778       NaN        NaN
#              211737071       NaN        NaN
#              211737822       NaN        NaN
#              211740544       NaN        NaN
#              234375861       NaN        NaN
#              234375862       NaN        NaN
#              234376477       NaN        NaN
#              247142027       NaN        NaN
#
#                                                                      nodes  \
# element_type osmid
# node         4433052949                                                NaN
#              6199734157                                                NaN
# way          211713778   [2216849423, 2216849422, 2216849421, 221684941...
#              211737071   [2217010201, 2217010194, 2217010207, 221701020...
#              211737822   [2217021130, 2217021137, 2217021141, 221702114...
#              211740544   [2217046479, 2217046497, 2217046454, 221704647...
#              234375861   [2426282609, 2426282612, 2426282595, 242628260...
#              234375862   [2426282610, 2426282585, 2426282616, 242628259...
#              234376477   [2426287429, 2426287449, 2426287445, 242628743...
#              247142027   [2540799408, 2540799312, 2540799346, 254079934...
#
#                         area addr:city building  ... name_1 Colonia  \
# element_type osmid                               ...
# node         4433052949  NaN       NaN      NaN  ...    NaN     NaN
#              6199734157  NaN       NaN      NaN  ...    NaN     NaN
# way          211713778   NaN       NaN      NaN  ...    NaN     NaN
#              211737071   NaN       NaN      NaN  ...    NaN     NaN
#              211737822   NaN       NaN      NaN  ...    NaN     NaN
#              211740544   NaN       NaN      NaN  ...    NaN     NaN
#              234375861   NaN       NaN      NaN  ...    NaN     NaN
#              234375862   NaN       NaN      NaN  ...    NaN     NaN
#              234376477   NaN       NaN      NaN  ...    NaN     NaN
#              247142027   NaN       NaN      NaN  ...    NaN     NaN
#
#                         created_by colonia addr:housename email  \
# element_type osmid
# node         4433052949        NaN     NaN            NaN   NaN
#              6199734157        NaN     NaN            NaN   NaN
# way          211713778         NaN     NaN            NaN   NaN
#              211737071         NaN     NaN            NaN   NaN
#              211737822         NaN     NaN            NaN   NaN
#              211740544         NaN     NaN            NaN   NaN
#              234375861         NaN     NaN            NaN   NaN
#              234375862         NaN     NaN            NaN   NaN
#              234376477         NaN     NaN            NaN   NaN
#              247142027         NaN     NaN            NaN   NaN
#
#                         building:levels sport_1 sport_2 postal_code
# element_type osmid
# node         4433052949             NaN     NaN     NaN         NaN
#              6199734157             NaN     NaN     NaN         NaN
# way          211713778              NaN     NaN     NaN         NaN
#              211737071              NaN     NaN     NaN         NaN
#              211737822              NaN     NaN     NaN         NaN
#              211740544              NaN     NaN     NaN         NaN
#              234375861              NaN     NaN     NaN         NaN
#              234375862              NaN     NaN     NaN         NaN
#              234376477              NaN     NaN     NaN         NaN
#              247142027              NaN     NaN     NaN         NaN
#
# [10 rows x 77 columns]

# %% [markdown]
# ## **SOLO PARQUES → OPEN STREET MAPS**

# %%
Parque= AreaV.drop(AreaV[AreaV['leisure']!='park'].index)
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
Parque.head()
# Out:
#                        leisure             name sport  \
# element_type osmid
# way          211713778    park  Plaza Principal   NaN
#              211737071    park  Plaza Principal   NaN
#              234375861    park              NaN   NaN
#              247142027    park              NaN   NaN
#              251580754    park              NaN   NaN
#
#                                                                  geometry  \
# element_type osmid
# way          211713778  POLYGON ((-100.51092 20.14931, -100.51091 20.1...
#              211737071  POLYGON ((-100.51668 20.00401, -100.51613 20.0...
#              234375861  POLYGON ((-100.51150 20.14845, -100.51095 20.1...
#              247142027  POLYGON ((-100.80569 20.28354, -100.80532 20.2...
#              251580754  POLYGON ((-100.81359 20.29631, -100.81330 20.2...
#
#                        access wheelchair  \
# element_type osmid
# way          211713778    NaN        NaN
#              211737071    NaN        NaN
#              234375861    NaN        NaN
#              247142027    NaN        NaN
#              251580754    NaN        NaN
#
#                                                                     nodes  \
# element_type osmid
# way          211713778  [2216849423, 2216849422, 2216849421, 221684941...
#              211737071  [2217010201, 2217010194, 2217010207, 221701020...
#              234375861  [2426282609, 2426282612, 2426282595, 242628260...
#              247142027  [2540799408, 2540799312, 2540799346, 254079934...
#              251580754  [2577840741, 2577840735, 2577840751, 257784074...
#
#                        area addr:city building  ... name_1 Colonia created_by  \
# element_type osmid                              ...
# way          211713778  NaN       NaN      NaN  ...    NaN     NaN        NaN
#              211737071  NaN       NaN      NaN  ...    NaN     NaN        NaN
#              234375861  NaN       NaN      NaN  ...    NaN     NaN        NaN
#              247142027  NaN       NaN      NaN  ...    NaN     NaN        NaN
#              251580754  NaN       NaN      NaN  ...    NaN     NaN        NaN
#
#                        colonia addr:housename email building:levels sport_1  \
# element_type osmid
# way          211713778     NaN            NaN   NaN             NaN     NaN
#              211737071     NaN            NaN   NaN             NaN     NaN
#              234375861     NaN            NaN   NaN             NaN     NaN
#              247142027     NaN            NaN   NaN             NaN     NaN
#              251580754     NaN            NaN   NaN             NaN     NaN
#
#                        sport_2 postal_code
# element_type osmid
# way          211713778     NaN         NaN
#              211737071     NaN         NaN
#              234375861     NaN         NaN
#              247142027     NaN         NaN
#              251580754     NaN         NaN
#
# [5 rows x 77 columns]

# %%
Parque.crs
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
frames = [Parque]

# %%
Parques=pd.concat(frames)

# %%
Parques.shape
# Out:
# (1329, 77)

# %%
Parques=Parques.to_crs(epsg=6372)
Parques.head()
AGEBS=AGEBS.to_crs(epsg=6372)

# %% [markdown]
# ## **PLOTEO PARQUES → INEGI**

# %%
colors = ['#A1E2E6', '#E6BDA1', '#B3A16B', '#678072', '#524A4A']

# %%
Parque_Inegi = gpd.clip(Area_Verde, AGEBS)
Parque_Inegi.head()
# Out:
#       CVEGEO CVE_ENT CVE_MUN CVE_LOC  CONDICION GEOGRAFICO    NOMSERV  \
# 0  110370001      11     037    0001  No Aplica   Camellón  No Aplica
# 1  110370001      11     037    0001  No Aplica   Camellón  No Aplica
# 2  110370001      11     037    0001  No Aplica   Camellón  No Aplica
# 3  110370001      11     037    0001  No Aplica   Camellón  No Aplica
# 4  110370001      11     037    0001  No Aplica   Camellón  No Aplica
#
#        TIPO  CVE_SERV  AMBITO  \
# 0  Camellón         1  Urbana
# 1  Camellón         2  Urbana
# 2  Camellón         3  Urbana
# 3  Camellón         4  Urbana
# 4  Camellón         5  Urbana
#
#                                             geometry
# 0  POLYGON ((2558110.623 994028.035, 2558111.016 ...
# 1  POLYGON ((2557191.720 993825.861, 2557191.354 ...
# 2  POLYGON ((2560931.757 993133.321, 2560929.100 ...
# 3  POLYGON ((2558487.624 993485.175, 2558487.453 ...
# 4  POLYGON ((2560474.997 993645.404, 2560475.482 ...

# %%
Parques_Leon= AGEBS.plot(color= colors[2], alpha=.2, figsize=(16, 18))
Parque_Inegi.plot(ax=Parques_Leon, color= '#039e7d',linewidth= 1.5)
plt.title("ZM DE LEÓN \n ÁREAS VERDES DE INEGI", fontsize=25, color= '#03989e')
plt.axis('off')
plt.show()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
Parque_Clip = gpd.clip(Parques, AGEBS)
Parque_Clip.head()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                         leisure                   name sport  \
# element_type osmid
# node         5767198091    park         Paqrque sopeña   NaN
#              5767253525    park  Parque Felice Bonetto   NaN
#              6389770858    park     Parque Santa Lucia   NaN
#              6389770859    park   Parque Santa Lucia 2   NaN
#              6389770860    park   Parque Santa Lucia 3   NaN
#
#                                                 geometry access wheelchair  \
# element_type osmid
# node         5767198091   POINT (2559908.549 994926.695)    NaN        NaN
#              5767253525   POINT (2559652.699 992791.488)    NaN        NaN
#              6389770858  POINT (2541321.580 1005602.396)    NaN        NaN
#              6389770859  POINT (2541184.672 1005539.114)    NaN        NaN
#              6389770860  POINT (2541426.180 1005508.892)    NaN        NaN
#
#                         nodes area addr:city building  ... name_1 Colonia  \
# element_type osmid                                     ...
# node         5767198091   NaN  NaN       NaN      NaN  ...    NaN     NaN
#              5767253525   NaN  NaN       NaN      NaN  ...    NaN     NaN
#              6389770858   NaN  NaN       NaN      NaN  ...    NaN     NaN
#              6389770859   NaN  NaN       NaN      NaN  ...    NaN     NaN
#              6389770860   NaN  NaN       NaN      NaN  ...    NaN     NaN
#
#                         created_by colonia addr:housename email  \
# element_type osmid
# node         5767198091        NaN     NaN            NaN   NaN
#              5767253525        NaN     NaN            NaN   NaN
#              6389770858        NaN     NaN            NaN   NaN
#              6389770859        NaN     NaN            NaN   NaN
#              6389770860        NaN     NaN            NaN   NaN
#
#                         building:levels sport_1 sport_2 postal_code
# element_type osmid
# node         5767198091             NaN     NaN     NaN         NaN
#              5767253525             NaN     NaN     NaN         NaN
#              6389770858             NaN     NaN     NaN         NaN
#              6389770859             NaN     NaN     NaN         NaN
#              6389770860             NaN     NaN     NaN         NaN
#
# [5 rows x 77 columns]

# %% [markdown]
# ## **PLOTEO PARQUES → OPEN STREET MAPS**

# %%
Parques_LEON_OSM= AGEBS.plot(color=colors[3], alpha=0.2, figsize=(16,18))
Parque_Clip.plot(ax=Parques_LEON_OSM, color= '#039e7d')
plt.title("ZM LEÓN \n ÁREAS VERDES DE OPEN STREET MAP", fontsize=25, color= '#03989e')
plt.axis('off')
plt.show()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
AGEBS.crs
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <Projected CRS: EPSG:6372>
# Name: Mexico ITRF2008 / LCC
# Axis Info [cartesian]:
# - N[north]: Northing (metre)
# - E[east]: Easting (metre)
# Area of Use:
# - name: Mexico - onshore and offshore.
# - bounds: (-122.19, 12.1, -84.64, 32.72)
# Coordinate Operation:
# - name: Mexico LCC
# - method: Lambert Conic Conformal (2SP)
# Datum: Mexico ITRF2008
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
Parque_Clip = gpd.clip(Parques, AGEBS)
Parque_Clip.head()
# Out:
#                         leisure                   name sport  \
# element_type osmid
# node         5767198091    park         Paqrque sopeña   NaN
#              5767253525    park  Parque Felice Bonetto   NaN
#              6389770858    park     Parque Santa Lucia   NaN
#              6389770859    park   Parque Santa Lucia 2   NaN
#              6389770860    park   Parque Santa Lucia 3   NaN
#
#                                                 geometry access wheelchair  \
# element_type osmid
# node         5767198091   POINT (2559908.549 994926.695)    NaN        NaN
#              5767253525   POINT (2559652.699 992791.488)    NaN        NaN
#              6389770858  POINT (2541321.580 1005602.396)    NaN        NaN
#              6389770859  POINT (2541184.672 1005539.114)    NaN        NaN
#              6389770860  POINT (2541426.180 1005508.892)    NaN        NaN
#
#                         nodes area addr:city building  ... name_1 Colonia  \
# element_type osmid                                     ...
# node         5767198091   NaN  NaN       NaN      NaN  ...    NaN     NaN
#              5767253525   NaN  NaN       NaN      NaN  ...    NaN     NaN
#              6389770858   NaN  NaN       NaN      NaN  ...    NaN     NaN
#              6389770859   NaN  NaN       NaN      NaN  ...    NaN     NaN
#              6389770860   NaN  NaN       NaN      NaN  ...    NaN     NaN
#
#                         created_by colonia addr:housename email  \
# element_type osmid
# node         5767198091        NaN     NaN            NaN   NaN
#              5767253525        NaN     NaN            NaN   NaN
#              6389770858        NaN     NaN            NaN   NaN
#              6389770859        NaN     NaN            NaN   NaN
#              6389770860        NaN     NaN            NaN   NaN
#
#                         building:levels sport_1 sport_2 postal_code
# element_type osmid
# node         5767198091             NaN     NaN     NaN         NaN
#              5767253525             NaN     NaN     NaN         NaN
#              6389770858             NaN     NaN     NaN         NaN
#              6389770859             NaN     NaN     NaN         NaN
#              6389770860             NaN     NaN     NaN         NaN
#
# [5 rows x 77 columns]

# %%
Parque_Clips = gpd.clip(Area_Verde, AGEBS)
Parque_Clips.head()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#       CVEGEO CVE_ENT CVE_MUN CVE_LOC  CONDICION GEOGRAFICO    NOMSERV  \
# 0  110370001      11     037    0001  No Aplica   Camellón  No Aplica
# 1  110370001      11     037    0001  No Aplica   Camellón  No Aplica
# 2  110370001      11     037    0001  No Aplica   Camellón  No Aplica
# 3  110370001      11     037    0001  No Aplica   Camellón  No Aplica
# 4  110370001      11     037    0001  No Aplica   Camellón  No Aplica
#
#        TIPO  CVE_SERV  AMBITO  \
# 0  Camellón         1  Urbana
# 1  Camellón         2  Urbana
# 2  Camellón         3  Urbana
# 3  Camellón         4  Urbana
# 4  Camellón         5  Urbana
#
#                                             geometry
# 0  POLYGON ((2558110.623 994028.035, 2558111.016 ...
# 1  POLYGON ((2557191.720 993825.861, 2557191.354 ...
# 2  POLYGON ((2560931.757 993133.321, 2560929.100 ...
# 3  POLYGON ((2558487.624 993485.175, 2558487.453 ...
# 4  POLYGON ((2560474.997 993645.404, 2560475.482 ...

# %% [markdown]
# ##**Parques OSM, solamente de la zona metropolitana**

# %%
Parques_LEON_OSM2= AGEBS.plot(color=colors[2], alpha=0.2, figsize=(16, 18))
Parque_Clip.plot(ax=Parques_LEON_OSM2, color='#039e7d')
plt.title("ZM de LEÓN \n Áreas Verdes de Open Street Map", fontsize=25, color= '#03989e')
plt.axis('off')
plt.show()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
AreaV.crs
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
AreaV_INEGI=Parque_Clips.to_crs(epsg=3857)
AreaV_OSM=Parque_Clip.to_crs(epsg=3857)

# %% [markdown]
# ## **PLOTEO → INEGI & POBREZA**

# %%
fig, ax = plt.subplots(1,figsize=(16, 18)) 
Base = Pobreza_A.plot(column='Pobre_AV',  
              alpha=1, 
              scheme='NaturalBreaks', 
              legend=True, 
              cmap='YlOrRd',
              classification_kwds={'k':5},
              figsize=(8,8),
              ax=ax)
AreaV_INEGI.plot(ax=Base, color='#039e7d')
plt.title("Rango de Pobreza (%) en la ZM de León \n Áreas Verdes de INEGI", fontsize=25, color = '#03989e')
ax.set_axis_off() 
#ctx.add_basemap(ax, source=ctx.providers.Stamen.TonerLite, alpha=0.3)
plt.show()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ## **PLOTEO → OSM & POBREZA**

# %%
fig, ax = plt.subplots(1,figsize=(16, 18)) 
Base = Pobreza_A.plot(column='Pobre_AV',  
              alpha=1, 
              scheme='NaturalBreaks', 
              legend=True, 
              cmap='YlOrRd',
              classification_kwds={'k':5},
              figsize=(8,8),
              ax=ax)
AreaV_OSM.plot(ax=Base, color='#039e7d')
plt.title("Rango de Pobreza (%) en la ZM de León \n Áreas Verdes de Open Street Map", fontsize=25, color = '#03989e')
ax.set_axis_off() 
#ctx.add_basemap(ax, source=ctx.providers.Stamen.TonerLite, alpha=0.3)
plt.show()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
